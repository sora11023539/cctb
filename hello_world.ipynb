# %% [markdown]
# <a href="https://colab.research.google.com/github/sora11023539/cctb/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/sora11023539/cctb/refs/heads/main/exercise_data.csv"
data = pd.read_csv(url)
# data = pd.read_csv("./sample_data/exercise_data.csv")
data.head()
data.plot(kind='line', subplots=True)
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
from datetime import date
print(date.today().year)
print(date.today().month)
print(date.today())

from datetime import datetime
current_time = datetime.now()
print(current_time)

data['DifferenceOfPulse'] = data['Maxpulse'] - data['Pulse']
data.head()

data['Calories'] = data['Calories'].fillna(data['Calories'].mean())
print("Mean of Maxpulse is:", data['Maxpulse'].mean())
print("Median of Maxpulse is:", data['Maxpulse'].median())
print("Mode of Maxpulse is:", data['Maxpulse'].mode()[0])

data.isnull().sum()

data_cleaned = data.dropna()
data_cleaned.isnull().sum()
# Out:
# 2025
# 1
# 2025-01-23
# 2025-01-23 02:47:45.232938
# Mean of Maxpulse is: 128.5
# Median of Maxpulse is: 127.5
# Mode of Maxpulse is: 120
# Duration             0
# Date                 0
# Pulse                0
# Maxpulse             0
# Calories             0
# DifferenceOfPulse    0
# dtype: int64

# %%
import pandas as pd
import numpy as np

#Creating Data frame
tempData = pd.DataFrame({
    'Age': [25, 30, np.nan, 35, 40],
    'Salary': [50000, 60000, 55000, np.nan, 65000],
    'City': ['New York', 'San Francisco', np.nan, 'Chicago', 'New York']
})

print(tempData)
# Out:
#     Age   Salary           City
# 0  25.0  50000.0       New York
# 1  30.0  60000.0  San Francisco
# 2   NaN  55000.0            NaN
# 3  35.0      NaN        Chicago
# 4  40.0  65000.0       New York

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url = "https://raw.githubusercontent.com/sora11023539/cctb/refs/heads/main/exercise_data.csv"
data = pd.read_csv(url)

data.plot(kind='scatter', x='Pulse', y='Maxpulse', alpha=0.6)
plt.title('Pulse vs Maxpulse')
plt.show()

numerical_data = data.drop(columns=['Date'])
numerical_data.head()

# Generate the correlation matrix
correlation_matrix = numerical_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000  0.004410  0.049959 -0.114169
# Pulse     0.004410  1.000000  0.276583  0.513186
# Maxpulse  0.049959  0.276583  1.000000  0.357460
# Calories -0.114169  0.513186  0.357460  1.000000
